# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.google.android.apps.youtube.music',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=5000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])

data = data.join(pd.DataFrame(data.pop('review').tolist()))

data
# Out:
#                                   reviewId          userName  \
# 0     baf9417d-5181-419f-8143-5ded69a893e4   Pengguna Google
# 1     4a2cfbe1-285e-46d2-927f-7aa59106f2cc   Pengguna Google
# 2     fdb5ace7-9d18-4232-ac54-138d675ff093   Pengguna Google
# 3     40796e7a-46da-4e58-a5ca-4911d0684459   Pengguna Google
# 4     cdb950c9-20c2-4af5-a86f-abcb27d5b2b6   Pengguna Google
# ...                                    ...               ...
# 4995  85a53bb3-ceb2-4228-8e4b-54ad0841fa90     Refsa Pratama
# 4996  4459ead5-140b-47be-bfb3-e327b07f6d1e      Tri Yogianto
# 4997  7c643de8-73b2-4601-ac3d-d2c25addaafb         Heri Heri
# 4998  45dac858-998f-4911-9b7e-d6f3a3f46970         Rapki Tok
# 4999  a24ca6b3-9ba1-4e62-93f2-51c73a07b0d1  Muh Fatur rahman
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 4995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4999  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                 content  score  thumbsUpCount  \
# 0     Enaknya pake yt music sepaket sama YouTube pre...      4             30
# 1     Overall emang bagus dibandingkan dengan Spotif...      1            202
# 2     Hai Google, saya cukup kecewa dengan kualitas ...      2             54
# 3     Baru instal lagi setelah sekian lama, aplikasi...      5            675
# 4     Saya pengguna premium. Pertama pake selalu sal...      1           1781
# ...                                                 ...    ...            ...
# 4995  Jangan pernah kalian download app ini. Kalau k...      1              1
# 4996  Balikin Google play music seperti sebelumnya, ...      1             16
# 4997              Tolong ditambah kan lagu paling bagus      3              0
# 4998  Ya nih tadi nya bisa di puter latar belakang s...      2              0
# 4999  Aplikasinya Sangat Bagus Dan Artis Penyanyi Se...      4              3
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                 7.07.51 2024-07-05 22:31:29         None      None
# 1                 7.07.51 2024-07-05 04:03:05         None      None
# 2                 7.07.51 2024-06-28 13:58:06         None      None
# 3                 7.06.53 2024-06-22 07:32:51         None      None
# 4                 6.51.52 2024-05-10 21:39:41         None      None
# ...                   ...                 ...          ...       ...
# 4995                 None 2020-07-01 11:40:01         None      None
# 4996              3.89.52 2020-10-22 02:55:50         None      None
# 4997                 None 2020-11-06 20:29:23         None      None
# 4998              3.45.54 2021-02-09 21:52:31         None      None
# 4999              4.21.50 2021-04-05 09:32:01         None      None
#
#      appVersion
# 0       7.07.51
# 1       7.07.51
# 2       7.07.51
# 3       7.06.53
# 4       6.51.52
# ...         ...
# 4995       None
# 4996    3.89.52
# 4997       None
# 4998    3.45.54
# 4999    4.21.50
#
# [5000 rows x 11 columns]

# %%
data.to_csv('youtubemusic.csv', index=False)
